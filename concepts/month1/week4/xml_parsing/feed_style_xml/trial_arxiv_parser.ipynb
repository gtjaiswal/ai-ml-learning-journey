# %%
import feedparser
feed = feedparser.parse("Arxiv_Sample_Feed.xml")
feed
# Out:
# {'bozo': 1,
#  'entries': [{'id': 'http://arxiv.org/abs/hep-ex/0307015',
#    'guidislink': True,
#    'link': 'http://arxiv.org/abs/hep-ex/0307015v1',
#    'published': '2003-07-07T13:46:39-04:00',
#    'published_parsed': time.struct_time(tm_year=2003, tm_mon=7, tm_mday=7, tm_hour=17, tm_min=46, tm_sec=39, tm_wday=0, tm_yday=188, tm_isdst=0),
#    'updated': '2003-07-07T13:46:39-04:00',
#    'updated_parsed': time.struct_time(tm_year=2003, tm_mon=7, tm_mday=7, tm_hour=17, tm_min=46, tm_sec=39, tm_wday=0, tm_yday=188, tm_isdst=0),
#    'title': 'Multi-Electron Production at High Transverse Momenta in ep Collisions at\n      HERA',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': '',
#     'value': 'Multi-Electron Production at High Transverse Momenta in ep Collisions at\n      HERA'},
# ...

# %%
feed.feed
# Out:
# {'links': [{'xmlns': 'http://www.w3.org/2005/Atom',
#    'href': 'http://arxiv.org/api/query?search_query=all:electron&id_list=&start=0&max_results=1',
#    'rel': 'self',
#    'type': 'application/atom+xml'}],
#  'title': 'ArXiv Query: search_query=all:electron&id_list=&start=0&max_results=1',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': '',
#   'value': 'ArXiv Query: search_query=all:electron&id_list=&start=0&max_results=1'},
#  'id': 'http://arxiv.org/api/cHxbiOdZaP56ODnBPIenZhzg5f8',
#  'guidislink': True,
#  'link': 'http://arxiv.org/api/cHxbiOdZaP56ODnBPIenZhzg5f8',
#  'updated': '2007-10-08T00:00:00-04:00',
#  'updated_parsed': time.struct_time(tm_year=2007, tm_mon=10, tm_mday=8, tm_hour=4, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=281, tm_isdst=0),
#  'opensearch_totalresults': {'xmlns:opensearch': 'http://a9.com/-/spec/opensearch/1.1/'},
#  'opensearch_startindex': {'xmlns:opensearch': 'http://a9.com/-/spec/opensearch/1.1/'},
# ...

# %%
print(feed.feed.title)
print(feed.feed.links[0])
print(feed.feed.id)
print(feed.feed.updated)
print(feed.keys())
# print(feed.items())
# Out:
# ArXiv Query: search_query=all:electron&id_list=&start=0&max_results=1
# {'xmlns': 'http://www.w3.org/2005/Atom', 'href': 'http://arxiv.org/api/query?search_query=all:electron&id_list=&start=0&max_results=1', 'rel': 'self', 'type': 'application/atom+xml'}
# http://arxiv.org/api/cHxbiOdZaP56ODnBPIenZhzg5f8
# 2007-10-08T00:00:00-04:00
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'encoding', 'version', 'bozo_exception', 'namespaces'])

# %%
print(feed.feed.keys())
print(feed.feed.opensearch_totalresults.items())
# feed.feed.opensearch_totalresults
# Out:
# dict_keys(['links', 'title', 'title_detail', 'id', 'guidislink', 'link', 'updated', 'updated_parsed', 'opensearch_totalresults', 'opensearch_startindex', 'opensearch_itemsperpage'])
# dict_items([('xmlns:opensearch', 'http://a9.com/-/spec/opensearch/1.1/')])

# %%
for k, v in feed.feed.items():
    print(k, "=>", v)
# Out:
# links => [{'xmlns': 'http://www.w3.org/2005/Atom', 'href': 'http://arxiv.org/api/query?search_query=all:electron&id_list=&start=0&max_results=1', 'rel': 'self', 'type': 'application/atom+xml'}]
# title => ArXiv Query: search_query=all:electron&id_list=&start=0&max_results=1
# title_detail => {'type': 'text/plain', 'language': None, 'base': '', 'value': 'ArXiv Query: search_query=all:electron&id_list=&start=0&max_results=1'}
# id => http://arxiv.org/api/cHxbiOdZaP56ODnBPIenZhzg5f8
# guidislink => True
# link => http://arxiv.org/api/cHxbiOdZaP56ODnBPIenZhzg5f8
# updated => 2007-10-08T00:00:00-04:00
# updated_parsed => time.struct_time(tm_year=2007, tm_mon=10, tm_mday=8, tm_hour=4, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=281, tm_isdst=0)
# opensearch_totalresults => {'xmlns:opensearch': 'http://a9.com/-/spec/opensearch/1.1/'}
# opensearch_startindex => {'xmlns:opensearch': 'http://a9.com/-/spec/opensearch/1.1/'}
# ...
