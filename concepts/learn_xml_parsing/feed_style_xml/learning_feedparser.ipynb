# %%
from itertools import count

import feedparser

feed = feedparser.parse("../custom_namespace_xml/news_basic.xml")
# Out:
# ('bozo', False)
# ...

# %%
feed
# Out:
# {'bozo': False,
#  'entries': [{'title': 'City Park Renovation Completed',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': '',
#     'value': 'City Park Renovation Completed'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://example.com/news1'}],
#    'link': 'https://example.com/news1',
#    'published': 'Mon, 01 Dec 2025 10:00:00 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=12, tm_mday=1, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=335, tm_isdst=0),
#    'summary': 'The city park renovation was finished ahead of schedule.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': '',
#     'value': 'The city park renovation was finished ahead of schedule.'}},
#   {'title': 'New Library Opens Downtown',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': '',
#     'value': 'New Library Opens Downtown'},
# ...

# %%
feed.items()
# Out:
# dict_items([('bozo', False), ('entries', [{'title': 'City Park Renovation Completed', 'title_detail': {'type': 'text/plain', 'language': None, 'base': '', 'value': 'City Park Renovation Completed'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://example.com/news1'}], 'link': 'https://example.com/news1', 'published': 'Mon, 01 Dec 2025 10:00:00 GMT', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=12, tm_mday=1, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=335, tm_isdst=0), 'summary': 'The city park renovation was finished ahead of schedule.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': '', 'value': 'The city park renovation was finished ahead of schedule.'}}, {'title': 'New Library Opens Downtown', 'title_detail': {'type': 'text/plain', 'language': None, 'base': '', 'value': 'New Library Opens Downtown'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://example.com/news2'}], 'link': 'https://example.com/ne
# ...

# %%
feed.feed
# Out:
# {'title': 'Daily News Feed',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': '',
#   'value': 'Daily News Feed'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://example.com'}],
#  'link': 'https://example.com',
#  'subtitle': 'Simple daily updates',
#  'subtitle_detail': {'type': 'text/html',
#   'language': None,
#   'base': '',
#   'value': 'Simple daily updates'}}

# %%
feed.feed.title
# Out:
# 'Daily News Feed'
